# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\ml\ecommerce-demand-forecasting\data\raw\online_retail_II.xlsx", sheet_name=None)

# %%
df
# Out:
# {'Year 2009-2010':        Invoice StockCode                          Description  Quantity  \
#  0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
#  1       489434    79323P                   PINK CHERRY LIGHTS        12
#  2       489434    79323W                  WHITE CHERRY LIGHTS        12
#  3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
#  4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#  ...        ...       ...                                  ...       ...
#  525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
#  525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
#  525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
#  525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
#  525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                 InvoiceDate  Price  Customer ID         Country
# ...

# %%
df_combined =pd.concat(df.values(),ignore_index=True)

# %%
df_combined.describe()
# Out:
#            Quantity                 InvoiceDate         Price    Customer ID
# count  1.067371e+06                     1067371  1.067371e+06  824364.000000
# mean   9.938898e+00  2011-01-02 21:13:55.394029  4.649388e+00   15324.638504
# min   -8.099500e+04         2009-12-01 07:45:00 -5.359436e+04   12346.000000
# 25%    1.000000e+00         2010-07-09 09:46:00  1.250000e+00   13975.000000
# 50%    3.000000e+00         2010-12-07 15:28:00  2.100000e+00   15255.000000
# 75%    1.000000e+01         2011-07-22 10:23:00  4.150000e+00   16797.000000
# max    8.099500e+04         2011-12-09 12:50:00  3.897000e+04   18287.000000
# std    1.727058e+02                         NaN  1.235531e+02    1697.464450

# %%
DF= df_combined

# %%
print(len(DF))
cancellation = DF[DF['Invoice'].astype(str).str.startswith('C')]
print(f"cancelation length : { len(cancellation)}")
df_clean = DF[~DF['Invoice'].astype(str).str.startswith('C')]
print((f"clean length : {len(df_clean)}"))
print(f" check :{len(df_clean)+ len(cancellation)} should equalto :{len(df)}")
# Out:
# 1067371
# cancelation length : 19494
# clean length : 1047877
#  check :1067371 should equalto :2

# %%
print(DF['InvoiceDate'].min())
print(DF['InvoiceDate'].max())
# Out:
# 2009-12-01 07:45:00
# 2011-12-09 12:50:00
